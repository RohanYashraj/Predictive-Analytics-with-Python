# %% [markdown]
# # Gradient Boosting Classification with Scikit-Learn
# We will be using the breast cancer dataset that is prebuilt into scikit-learn to use as example data. First off, let’s get some imports out of the way:

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import classification_report
from sklearn.model_selection import KFold, train_test_split
from sklearn.datasets import load_breast_cancer
from sklearn.ensemble import GradientBoostingClassifier

seed = 999

# %% [markdown]
# Here, we are just importing pandas, numpy, our model, and a metric to evaluate our model’s performance.

# %%
df = pd.DataFrame(load_breast_cancer()['data'],
columns=load_breast_cancer()['feature_names'])
df['y'] = load_breast_cancer()['target']
df.head(5)
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                 0.07871  ...          17.33           184.60      2019.0
# 1                 0.05667  ...          23.41           158.80      1956.0
# 2                 0.05999  ...          25.53           152.50      1709.0
# 3                 0.09744  ...          26.50            98.87       567.7
# 4                 0.05883  ...          16.67           152.20      1575.0
#
#    worst smoothness  worst compactness  worst concavity  worst concave points  \
# 0            0.1622             0.6656           0.7119                0.2654
# 1            0.1238             0.1866           0.2416                0.1860
# 2            0.1444             0.4245           0.4504                0.2430
# 3            0.2098             0.8663           0.6869                0.2575
# 4            0.1374             0.2050           0.4000                0.1625
#
#    worst symmetry  worst fractal dimension  y
# 0          0.4601                  0.11890  0
# 1          0.2750                  0.08902  0
# 2          0.3613                  0.08758  0
# 3          0.6638                  0.17300  0
# 4          0.2364                  0.07678  0
#
# [5 rows x 31 columns]

# %%
X = df.iloc[:, :-1]
y = df.iloc[:, -1]
Xtrain, Xtest, ytrain, ytest = train_test_split(X, y, test_size = .33, stratify = y, random_state = seed)

# %%
df.shape
# Out:
# (569, 31)

# %% [markdown]
# For convenience sake, we will convert the data into a DataFrame because it’s easier to manipulate that way. Feel free to skip this step.

# %% [markdown]
# Here, we define our features and our label, and split ur data into a train and validation using 5 Fold cross validation.

# %%
gradient_booster = GradientBoostingClassifier(learning_rate=0.1)
gradient_booster.get_params()
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'deviance',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# There is a lot of parameters here, so I will only cover the most important:
# - Criterion: The loss function used to find the optimal feature and threshold to split the data
# - learning_rate: this parameter scales the contribution of each tree
# - max_depth: the maximum depth of each tree
# - n_estimators: the number of trees to construct
# - init: the initial estimator. By default, it is the log(odds) converted to a probability(like we discussed before)

# %%
gradient_booster.fit(Xtrain,ytrain)
print(classification_report(ytest,gradient_booster.predict(Xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        70
#            1       0.97      0.99      0.98       118
#
#     accuracy                           0.98       188
#    macro avg       0.98      0.97      0.98       188
# weighted avg       0.98      0.98      0.98       188

# %%
from sklearn.model_selection import GridSearchCV

# %%
estimator = GradientBoostingClassifier()

# %%
rf_tuned_parameters = {"max_depth": [10, 20, 50, 100], 'n_estimators': [50, 100, 200, 500], 'min_samples_leaf': [10, 20, 50], 'learning_rate': [0.1, 0.01]}

# %%
cv_grid = GridSearchCV(estimator, param_grid = rf_tuned_parameters, scoring = 'roc_auc', verbose = 5) # 'recall', my_score
cv_grid.fit(Xtrain, ytrain)
# Out:
# Fitting 5 folds for each of 96 candidates, totalling 480 fits
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.3s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.4s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   2.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.8s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.9s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   1.2s
# [CV 5/5] END learning_rate=0.1, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.5s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   3.0s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.9s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.9s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   2.0s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   1.2s
# [CV 4/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   0.8s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.8s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.4s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.4s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   3.0s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 2/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 3/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 4/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 5/5] END learning_rate=0.1, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.5s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.5s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.9s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.5s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.2s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.9s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.2s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 1/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 2/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 3/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 4/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 5/5] END learning_rate=0.1, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   0.9s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   3.3s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   3.6s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   3.0s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.8s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=200; total time=   0.9s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   2.0s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 2/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 4/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=10, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=50; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=100; total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.2s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.9s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.8s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   3.1s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   0.8s
# [CV 2/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   0.8s
# [CV 4/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   0.8s
# [CV 5/5] END learning_rate=0.01, max_depth=20, min_samples_leaf=50, n_estimators=500; total time=   0.8s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.5s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.7s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.8s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=20, n_estimators=500; total time=   1.6s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=200; total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.1s
# [CV 3/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 4/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 5/5] END learning_rate=0.01, max_depth=50, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=50; total time=   0.2s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=100; total time=   0.5s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.0s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=200; total time=   1.1s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.5s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=10, n_estimators=500; total time=   2.6s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=50; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=100; total time=   0.3s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.6s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.7s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=200; total time=   0.8s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.8s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.8s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.8s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=20, n_estimators=500; total time=   1.7s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=50; total time=   0.0s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=100; total time=   0.1s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.3s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=200; total time=   0.4s
# [CV 1/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   1.0s
# [CV 2/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 3/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 4/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.9s
# [CV 5/5] END learning_rate=0.01, max_depth=100, min_samples_leaf=50, n_estimators=500; total time=   0.8s
# GridSearchCV(estimator=GradientBoostingClassifier(),
#              param_grid={'learning_rate': [0.1, 0.01],
#                          'max_depth': [10, 20, 50, 100],
#                          'min_samples_leaf': [10, 20, 50],
#                          'n_estimators': [50, 100, 200, 500]},
#              scoring='roc_auc', verbose=5)

# %%
best_parameters = cv_grid.best_estimator_.get_params()
best_parameters
# Out:
# {'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'deviance',
#  'max_depth': 100,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_impurity_split': None,
#  'min_samples_leaf': 10,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 500,
#  'n_iter_no_change': None,
#  'random_state': None,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %%
for param_name in sorted(rf_tuned_parameters.keys()):
    print("\t%s: %r" % (param_name, best_parameters[param_name]))
# Out:
# 	learning_rate: 0.1
# 	max_depth: 100
# 	min_samples_leaf: 10
# 	n_estimators: 500

# %%
print(classification_report(ytest,gradient_booster.predict(Xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.96      0.97        70
#            1       0.97      0.99      0.98       118
#
#     accuracy                           0.98       188
#    macro avg       0.98      0.97      0.98       188
# weighted avg       0.98      0.98      0.98       188

# %%
print(classification_report(ytest,cv_grid.predict(Xtest)))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96        70
#            1       0.97      0.97      0.97       118
#
#     accuracy                           0.97       188
#    macro avg       0.97      0.97      0.97       188
# weighted avg       0.97      0.97      0.97       188
